# %%
#EDA on Tips dataset

# %%
pwd
# Out:
# 'C:\\Users\\ABC\\3. Edureka\\15. Pandas and Numpy and EDA'

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir('C:\\Users\\ABC\\6. Datasets')

# %%
os.listdir()

# %%
df = pd.read_csv('tips.csv')
df['Tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: Tip, dtype: float64

# %%
df.head(5)
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns.unique()
# Out:
# Index(['Total_bill', 'Tip', 'Sex', 'Smoker', 'Day', 'Time', 'Size'], dtype='object')

# %%
a = df.describe(include='all').loc['unique'] #wheneer this comes it means its the loc of the command written!
a
# Out:
# Total_bill    NaN
# Tip           NaN
# Sex             2
# Smoker          2
# Day             4
# Time            2
# Size          NaN
# Name: unique, dtype: object

# %%
c = df.describe(include='all')
# Out:
#         Total_bill         Tip   Sex Smoker  Day    Time        Size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
unique_values = df.apply(lambda col: col.unique())
print(unique_values)
pd.DataFrame(unique_values)
# Out:
# Total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                              [Female, Male]
# Smoker                                                [No, Yes]
# Day                                       [Sun, Sat, Thur, Fri]
# Time                                            [Dinner, Lunch]
# Size                                         [2, 3, 4, 1, 6, 5]
# dtype: object
#                                                             0
# Total_bill  [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip         [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                            [Female, Male]
# Smoker                                              [No, Yes]
# Day                                     [Sun, Sat, Thur, Fri]
# Time                                          [Dinner, Lunch]
# Size                                       [2, 3, 4, 1, 6, 5]

# %%
unique_values_count = df.nunique()
unique_values_count
# Out:
# Total_bill    229
# Tip           123
# Sex             2
# Smoker          2
# Day             4
# Time            2
# Size            6
# dtype: int64

# %%
df.nunique()
# Out:
# Total_bill    229
# Tip           123
# Sex             2
# Smoker          2
# Day             4
# Time            2
# Size            6
# dtype: int64

# %%
aa = df.apply(lambda col: col.unique())
aa
# Out:
# Total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                              [Female, Male]
# Smoker                                                [No, Yes]
# Day                                       [Sun, Sat, Thur, Fri]
# Time                                            [Dinner, Lunch]
# Size                                         [2, 3, 4, 1, 6, 5]
# dtype: object

# %%
df['Tip'].describe()
# Out:
# count    244.000000
# mean       2.998279
# std        1.383638
# min        1.000000
# 25%        2.000000
# 50%        2.900000
# 75%        3.562500
# max       10.000000
# Name: Tip, dtype: float64

# %%
df.head()
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
a = df.groupby(['Sex', 'Smoker' , 'Time']).mean()
a
# Out:
#                       Total_bill       Tip      Size
# Sex    Smoker Time
# Female No     Dinner   20.004138  3.044138  2.655172
#               Lunch    15.902400  2.459600  2.520000
#        Yes    Dinner   18.215652  2.949130  2.217391
#               Lunch    17.431000  2.891000  2.300000
# Male   No     Dinner   20.130130  3.158052  2.766234
#               Lunch    18.486500  2.941500  2.500000
#        Yes    Dinner   23.642553  3.123191  2.595745
#               Lunch    17.374615  2.790769  2.153846

# %%
df.groupby(['Sex', 'Smoker' , 'Time']).count()
# Out:
#                       Total_bill  Tip  Day  Size
# Sex    Smoker Time
# Female No     Dinner          29   29   29    29
#               Lunch           25   25   25    25
#        Yes    Dinner          23   23   23    23
#               Lunch           10   10   10    10
# Male   No     Dinner          77   77   77    77
#               Lunch           20   20   20    20
#        Yes    Dinner          47   47   47    47
#               Lunch           13   13   13    13

# %%
b = df.groupby(['Smoker' , 'Sex', 'Day']).mean()
b
# Out:
#                     Total_bill       Tip      Size
# Smoker Sex    Day
# No     Female Fri    19.365000  3.125000  2.500000
#               Sat    19.003846  2.724615  2.307692
#               Sun    20.824286  3.329286  3.071429
#               Thur   16.014400  2.459600  2.480000
#        Male   Fri    17.475000  2.500000  2.000000
#               Sat    19.929063  3.256563  2.656250
#               Sun    20.403256  3.115349  2.883721
#               Thur   18.486500  2.941500  2.500000
# Yes    Female Fri    12.654286  2.682857  2.000000
#               Sat    20.266667  2.868667  2.200000
#               Sun    16.540000  3.500000  2.500000
#               Thur   19.218571  2.990000  2.428571
#        Male   Fri    20.452500  2.741250  2.125000
#               Sat    21.837778  2.879259  2.629630
#               Sun    26.141333  3.521333  2.600000
#               Thur   19.171000  3.058000  2.300000

# %%
df.groupby(['Size','Sex', 'Total_bill']).size().unstack()
# Out:
# Total_bill   3.07   5.75   7.25   7.51   7.56   7.74   8.35   8.51   8.52   \
# Size Sex
# 1    Female    1.0    NaN    1.0    NaN    NaN    NaN    NaN    NaN    NaN
#      Male      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2    Female    NaN    1.0    NaN    NaN    NaN    NaN    1.0    1.0    NaN
#      Male      NaN    NaN    1.0    1.0    1.0    1.0    NaN    NaN    1.0
# 3    Female    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      Male      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4    Female    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      Male      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5    Female    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#      Male      NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 6    Female    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...

# %%
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
results3 = df.groupby(['Day', 'Size']).size().unstack(fill_value = 0)
results3
# Out:
# Size  1   2   3   4  5  6
# Day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
df.groupby('Sex')['Day'].count()
# Out:
# Sex
# Female     87
# Male      157
# Name: Day, dtype: int64

# %%
df.groupby('Day')['Day'].count() #grouping the DataFrame df by the values in the 'Day' column and then selecting the 'Day' column from each group.
# Out:
# Day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: Day, dtype: int64

# %%
df.groupby('Day')['Day'].count()
# Out:
# Day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: Day, dtype: int64

# %%
result = df.groupby(['Day', 'Time']).size().unstack(fill_value=0)
result
# Out:
# Time  Dinner  Lunch
# Day
# Fri       12      7
# Sat       87      0
# Sun       76      0
# Thur       1     61

# %%
result2 = df.groupby(['Day', 'Time']).size().unstack(fill_value=0)
result2
# Out:
# Time  Dinner  Lunch
# Day
# Fri       12      7
# Sat       87      0
# Sun       76      0
# Thur       1     61

# %%
result3 = df.groupby(['Day', 'Time'])['Size'].sum()
result3
# Out:
# Day   Time
# Fri   Dinner     26
#       Lunch      14
# Sat   Dinner    219
# Sun   Dinner    216
# Thur  Dinner      2
#       Lunch     150
# Name: Size, dtype: int64

# %%
df['avg_bill_pp'] = df['Total_bill']/df['Size']
df.head()
# Out:
#    Total_bill   Tip     Sex Smoker  Day    Time  Size  avg_bill_pp
# 0       16.99  1.01  Female     No  Sun  Dinner     2     8.495000
# 1       10.34  1.66    Male     No  Sun  Dinner     3     3.446667
# 2       21.01  3.50    Male     No  Sun  Dinner     3     7.003333
# 3       23.68  3.31    Male     No  Sun  Dinner     2    11.840000
# 4       24.59  3.61  Female     No  Sun  Dinner     4     6.147500

# %%
df.reset_index()
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size  avg_bill_pp
# 0         16.99  1.01  Female     No   Sun  Dinner     2     8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3     3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3     7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2    11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4     6.147500
# ..          ...   ...     ...    ...   ...     ...   ...          ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2    13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2    11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2     8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2     9.390000
#
# [244 rows x 8 columns]

# %%
df.drop('avg_tip_pp', axis = 1 , inplace = True)

# %%
df['Total_bill'].sum()/df['Size'].sum()
# Out:
# 7.699792663476875

# %%
df['avg_bill_pp'].describe()
# Out:
# count    244.00000
# mean       7.88823
# std        2.91435
# min        2.87500
# 25%        5.80250
# 50%        7.25500
# 75%        9.39000
# max       20.27500
# Name: avg_bill_pp, dtype: float64

# %%
df2 = df.groupby('Size').sum().reset_index()
df2
# Out:
#    Size  Total_bill     Tip  avg_tip_pp  avg_bill_pp
# 0     1       28.97    5.75      28.970       28.970
# 1     2     2565.89  402.84    1282.945     1282.945
# 2     3      884.55  128.94     294.850      294.850
# 3     4     1058.70  153.01     264.675      264.675
# 4     5      150.34   20.14      30.068       30.068
# 5     6      139.32   20.90      23.220       23.220

# %%
df3 = df.groupby('Size').sum()
df3.corr()
# Out:
#             Total_bill       Tip
# Total_bill    1.000000  0.999252
# Tip           0.999252  1.000000

# %%
df2.corr()
# Out:
#                  Size  Total_bill       Tip  avg_bill_pp
# Size         1.000000   -0.361609 -0.371101    -0.418665
# Total_bill  -0.361609    1.000000  0.999252     0.976092
# Tip         -0.371101    0.999252  1.000000     0.983553
# avg_bill_pp -0.418665    0.976092  0.983553     1.000000

# %%
df2.rename(columns={'Total_bill': 'Total_BillSum', 'Tip': 'Total_Grouped_Tip'}, inplace = True)
df2
# Out:
#    Size  Total_BillSum  Total_Grouped_Tip  avg_tip_pp
# 0     1          28.97               5.75      28.970
# 1     2        2565.89             402.84    1282.945
# 2     3         884.55             128.94     294.850
# 3     4        1058.70             153.01     264.675
# 4     5         150.34              20.14      30.068
# 5     6         139.32              20.90      23.220

# %%
df2.drop('avg_tip_pp', axis = 1, inplace = True)
df2
# Out:
#    Size  Total_BillSum  Total_Grouped_Tip
# 0     1          28.97               5.75
# 1     2        2565.89             402.84
# 2     3         884.55             128.94
# 3     4        1058.70             153.01
# 4     5         150.34              20.14
# 5     6         139.32              20.90

# %%
df2['Average_Grouped_Tip'] = df2['Total_BillSum']/df2['Total_Grouped_Tip']
df2
# Out:
#    Size  Total_BillSum  Total_Grouped_Tip  Average_Grouped_Tip
# 0     1          28.97               5.75             5.038261
# 1     2        2565.89             402.84             6.369502
# 2     3         884.55             128.94             6.860168
# 3     4        1058.70             153.01             6.919156
# 4     5         150.34              20.14             7.464747
# 5     6         139.32              20.90             6.666029

# %%
plt.scatter(df2['Size'], df2['Average_Grouped_Tip'])

# %%
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size  avg_tip_pp
# 0         16.99  1.01  Female     No   Sun  Dinner     2    8.495000
# 1         10.34  1.66    Male     No   Sun  Dinner     3    3.446667
# 2         21.01  3.50    Male     No   Sun  Dinner     3    7.003333
# 3         23.68  3.31    Male     No   Sun  Dinner     2   11.840000
# 4         24.59  3.61  Female     No   Sun  Dinner     4    6.147500
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3    9.676667
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   13.590000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   11.335000
# 242       17.82  1.75    Male     No   Sat  Dinner     2    8.910000
# 243       18.78  3.00  Female     No  Thur  Dinner     2    9.390000
#
# [244 rows x 8 columns]

# %%
df2['Size'].count()
# Out:
# 6

# %%
df2['Size_count'] = df.groupby('Size')['Size'].count()
df2
# Out:
#    Size  Total_BillSum  Total_Grouped_Tip  Average_Grouped_Tip  Size_count
# 0     1          28.97               5.75             5.038261         NaN
# 1     2        2565.89             402.84             6.369502         4.0
# 2     3         884.55             128.94             6.860168       156.0
# 3     4        1058.70             153.01             6.919156        38.0
# 4     5         150.34              20.14             7.464747        37.0
# 5     6         139.32              20.90             6.666029         5.0

# %%
plt.scatter(df2['Size'], df2['avg_tip2'])

# %%
df2.columns
# Out:
# Index(['Size', 'Total_bill', 'Tip', 'avg_tip', 'avg_tip2'], dtype='object')

# %%
for k in range(1,7): #k is size
    dff = df[df['Size']==k]['Tip'].count()
    print("if k/size =", k,'the count is', dff)
# Out:
# if k/size = 1 the count is 4
# if k/size = 2 the count is 156
# if k/size = 3 the count is 38
# if k/size = 4 the count is 37
# if k/size = 5 the count is 5
# if k/size = 6 the count is 4

# %%
#Filter

# %%
dff = df[df['Size']==2]
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size   avg_tip
# 0         16.99  1.01  Female     No   Sun  Dinner     2  1.980198
# 3         23.68  3.31    Male     No   Sun  Dinner     2  0.604230
# 6          8.77  2.00    Male     No   Sun  Dinner     2  1.000000
# 8         15.04  1.96    Male     No   Sun  Dinner     2  1.020408
# 9         14.78  3.23    Male     No   Sun  Dinner     2  0.619195
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2  1.709402
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  1.000000
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  1.000000
# 242       17.82  1.75    Male     No   Sat  Dinner     2  1.142857
# 243       18.78  3.00  Female     No  Thur  Dinner     2  0.666667
#
# [156 rows x 8 columns]

# %%
df['avg_tip'].describe()
# Out:
# count    244.000000
# mean       0.962069
# std        0.388503
# min        0.300000
# 25%        0.666667
# 50%        0.902976
# 75%        1.159450
# max        2.500000
# Name: avg_tip, dtype: float64

# %%
plt.scatter(df['Tip'], df['Size'])
plt.xlabel('Tip')
plt.ylabel('Size')
# Out:
# Text(0, 0.5, 'Size')
