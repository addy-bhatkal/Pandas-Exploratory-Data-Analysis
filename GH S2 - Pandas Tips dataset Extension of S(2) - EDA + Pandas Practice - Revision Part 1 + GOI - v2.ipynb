# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir('C:\\Users\\ABC\\6. Datasets')
df = pd.read_csv('tips.csv')
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = df.reset_index()
df
# Out:
#      index  Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 1        1       10.34  1.66    Male     No   Sun  Dinner     3
# 2        2       21.01  3.50    Male     No   Sun  Dinner     3
# 3        3       23.68  3.31    Male     No   Sun  Dinner     2
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...         ...   ...     ...    ...   ...     ...   ...
# 239    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
"""dff = df[(df['Sex']=='Male') & (df['Day']=='Sun')]
dff
smoker = ['No']
e = dff['Smoker'].isin(smoker)
dff[e]"""

# %%
"""dff = df[(df['Smoker']=='No') & (df['Sex']=='Female')]
Day = ['Sun', 'Mon', 'Fri']
e = dff['Day'].isin(Day)
dff[e].nunique()"""

# %%
"""dff = df[(df['Sex']=='Male') | (df['Smoker']=='No')]
Day = ['Fri', 'Sat']
e = dff['Day'].isin(Day)
dff[e].nunique()"""

# %%
"""dff = df[(df['Sex']=='Female') & (df['Smoker']=='No')]
day = ['Sun', 'Sat', 'Thur']
e = dff['Day'].isin(day)
dff[e].nunique()"""

# %%
"""dff = df[(df['Sex']=='Female') & (df['Smoker']=='No')]
Day = ['Sun', 'Fri']
e = dff['Day'].isin(Day)
dff[e].nunique()"""

# %%
"""filt = df[(df['Sex']=='Male') & (df['Smoker']=='No')]
Day = ['Sat', 'Sun']
filt3 = df['Day'].isin(Day)
filt[filt3]"""

# %%
"""size = [2,3,4,5]
dff = df[df['Size'].isin(size)]
d4 = dff[(dff['Size']==4)]
listy = list(d4.index)
listy
e = dff[dff['index'].isin(listy)]
e"""

# %%
"""size = [2,4,6,7]
dff = df[df['Size'].isin(size)]
d6 = dff[dff['Size']==2]
listy = list(d6['index'])
listy
e = dff[dff['index'].isin(listy)]
e"""

# %%
"""size = [2,3,4,5]
df[df['Size'].isin(size)]
d = df[df['Size']==4]
listy = list(d['index'])
e = df[df['Smoker']=='No']
e_filtered = e[e['index'].isin(listy)]
e_filtered"""
# Out:
#      index  Total_bill   Tip     Sex Smoker   Day    Time  Size
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# 5        5       25.29  4.71    Male     No   Sun  Dinner     4
# 7        7       26.88  3.12    Male     No   Sun  Dinner     4
# 11      11       35.26  5.00  Female     No   Sun  Dinner     4
# 13      13       18.43  3.00    Male     No   Sun  Dinner     4
# 23      23       39.42  7.58    Male     No   Sat  Dinner     4
# 25      25       17.81  2.34    Male     No   Sat  Dinner     4
# 31      31       18.35  2.50    Male     No   Sat  Dinner     4
# 33      33       20.69  2.45  Female     No   Sat  Dinner     4
# 44      44       30.40  5.60    Male     No   Sun  Dinner     4
# 47      47       32.40  6.00    Male     No   Sun  Dinner     4
# 52      52       34.81  5.20  Female     No   Sun  Dinner     4
# 54      54       25.56  4.34    Male     No   Sun  Dinner     4
# 59      59       48.27  6.73    Male     No   Sat  Dinner     4
# ...

# %%
#Females with size 2 - used a listy index approach. 
size = [2,3,5,6]
dff = df[df['Size'].isin(size)]
d2 = dff[dff['Size']==2]
listy = list(d2['index'])
d3 = d2[d2['Sex']=='Female']
e = d3[d3['index'].isin(listy)]
e

"""WAY FASTER WAY 
#Females with size 2 - used a listy index approach. 

g = df.groupby(['Sex', 'Size'])
g.get_group(('Female', 2))"""
# Out:
#      index  Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 14      14       14.83  3.02  Female     No   Sun  Dinner     2
# 21      21       20.29  2.75  Female     No   Sat  Dinner     2
# 22      22       15.77  2.23  Female     No   Sat  Dinner     2
# 29      29       19.65  3.00  Female     No   Sat  Dinner     2
# 32      32       15.06  3.00  Female     No   Sat  Dinner     2
# 51      51       10.29  2.60  Female     No   Sun  Dinner     2
# 57      57       26.41  1.50  Female     No   Sat  Dinner     2
# 66      66       16.45  2.47  Female     No   Sat  Dinner     2
# 72      72       26.86  3.14  Female    Yes   Sat  Dinner     2
# 73      73       25.28  5.00  Female    Yes   Sat  Dinner     2
# 74      74       14.73  2.20  Female     No   Sat  Dinner     2
# 92      92        5.75  1.00  Female    Yes   Fri  Dinner     2
# 93      93       16.32  4.30  Female    Yes   Fri  Dinner     2
# ...

# %%
#Females with size 2 - used a listy index approach. 

a = df.groupby(['Sex', 'Size'])['Size'].sum().unstack()
a
# Out:
# Size    1    2   3    4   5   6
# Sex
# Female  3  116  42   36   5  12
# Male    1  196  72  112  20  12

# %%
c = list(df['Tip'] )

# %%
a = df.groupby(['Sex', 'Smoker'])
a.get_group(('Female', 'No')).nunique()
