# %%
#Handling Missing Data
import numpy as np 
import pandas as pd

# %%
#Python video 9 Handling missin data 

people = { 
    'first' : ['Alex', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last' : ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'], 
    'email' : ['CoreyMSchafer@gmail.com', 'JaneDoe@gmail.com','JaneDoe@gmail.com', None, np.nan,'Anonymous@gmail.com', 'NA' ], 
    'age' : ['33','55', '63','36', None, None, 'Missing' ]
}

# %%
df = pd.DataFrame(people)
df
# Out:
#    first     last                    email      age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JaneDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df8 = df[df['last'].str.contains('Doe')]
df8
# Out:
#   first last              email age
# 1  Jane  Doe  JaneDoe@gmail.com  55
# 2  John  Doe  JaneDoe@gmail.com  63

# %%
sheet = pd.read_csv('portuguesebank.csv')
sheet.head()
sheet
job = sheet.groupby('Job')
job.get_group('management')
# Out:
#        Age         Job Marital Status  Education Credit  Balance (euros)  \
# 0       58  management        married   tertiary     no             2143
# 5       35  management        married   tertiary     no              231
# 6       28  management         single   tertiary     no              447
# 21      56  management        married   tertiary     no              779
# 26      39  management         single   tertiary     no              255
# ...    ...         ...            ...        ...    ...              ...
# 45192   29  management         single   tertiary     no              765
# 45194   59  management        married   tertiary     no              138
# 45197   36  management         single  secondary     no             1511
# 45198   37  management        married   tertiary     no             1428
# 45201   53  management        married   tertiary     no              583
#
#       Housing Loan Personal Loan   Contact  Last Contact Day  \
# ...

# %%
#1
df.dropna(axis = 'index', how = 'any',  subset = ['email','age', 'last'], inplace = True)

# %%
df.dropna()
# Out:
#   first     last                    email      age
# 0  Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1  Jane      Doe        JaneDoe@gmail.com       55
# 2  John      Doe        JaneDoe@gmail.com       63
# 6    NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index', how = 'any')
# Out:
#   first     last                    email      age
# 0  Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1  Jane      Doe        JaneDoe@gmail.com       55
# 2  John      Doe        JaneDoe@gmail.com       63
# 6    NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index', how = 'any') #DIfference between this and the next one. 
#if i run it lke this it'll give me the desired output of lesser columns
# Out:
#   first     last                    email      age
# 0  Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1  Jane      Doe        JaneDoe@gmail.com       55
# 2  John      Doe        JaneDoe@gmail.com       63
# 6    NA  Missing                       NA  Missing

# %%
df 
#but noW WHEN I RUN THIS it goes back to og default because I havet usend the inplace = True arguement.
# Out:
#    first     last                    email      age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JaneDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df
df.dropna(axis = 'columns', how = 'any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6]

# %%
df
df.dropna(axis = 'columns', how = 'all')
# Out:
#    first     last                    email      age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JaneDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 4    NaN      NaN                      NaN     None
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index', how = 'any', subset = ['email'])
# Out:
#   first     last                    email      age
# 0  Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1  Jane      Doe        JaneDoe@gmail.com       55
# 2  John      Doe        JaneDoe@gmail.com       63
# 5  None      NaN      Anonymous@gmail.com     None
# 6    NA  Missing                       NA  Missing

# %%
df.dropna(axis = 'index', how = 'all', subset = ['email', 'last']) 
#Ive put all here so for a row to be dropped BOTH of ths subset columns need to be missing
# Out:
#    first     last                    email      age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1   Jane      Doe        JaneDoe@gmail.com       55
# 2   John      Doe        JaneDoe@gmail.com       63
# 3  Chris  Schafer                     None       36
# 5   None      NaN      Anonymous@gmail.com     None
# 6     NA  Missing                       NA  Missing

# %%
df = pd.DataFrame(people)
df.replace('NA', np.nan, inplace = True)
df.replace('Missing', np.nan, inplace = True)

# %%
df
# Out:
#    first     last                    email   age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@gmail.com    55
# 2   John      Doe        JaneDoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@gmail.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dropna()
# Out:
#   first     last                    email age
# 0  Alex  Schafer  CoreyMSchafer@gmail.com  33
# 1  Jane      Doe        JaneDoe@gmail.com  55
# 2  John      Doe        JaneDoe@gmail.com  63

# %%
df.dropna(axis = 'index', how = 'all', subset = ['email', 'last'])
# Out:
#    first     last                    email   age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@gmail.com    55
# 2   John      Doe        JaneDoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 5   None      NaN      Anonymous@gmail.com  None

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna('MISSING') #This is temp if inplace = True
# Out:
#      first     last                    email      age
# 0     Alex  Schafer  CoreyMSchafer@gmail.com       33
# 1     Jane      Doe        JaneDoe@gmail.com       55
# 2     John      Doe        JaneDoe@gmail.com       63
# 3    Chris  Schafer                  MISSING       36
# 4  MISSING  MISSING                  MISSING  MISSING
# 5  MISSING  MISSING      Anonymous@gmail.com  MISSING
# 6  MISSING  MISSING                  MISSING  MISSING

# %%
df.fillna(0) #This is temp if inplace = True
# Out:
#    first     last                    email age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com  33
# 1   Jane      Doe        JaneDoe@gmail.com  55
# 2   John      Doe        JaneDoe@gmail.com  63
# 3  Chris  Schafer                        0  36
# 4      0        0                        0   0
# 5      0        0      Anonymous@gmail.com   0
# 6      0        0                        0   0

# %%
df
# Out:
#    first     last                    email   age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com    33
# 1   Jane      Doe        JaneDoe@gmail.com    55
# 2   John      Doe        JaneDoe@gmail.com    63
# 3  Chris  Schafer                     None    36
# 4    NaN      NaN                      NaN  None
# 5   None      NaN      Anonymous@gmail.com  None
# 6    NaN      NaN                      NaN   NaN

# %%
df.dtypes #SEE ALL ARE objects which means it either a string or a set of other things
# Out:
# first    object
# last     object
# email    object
# age      object
# dtype: object

# %%
#Whwn we have NaN we can use float as NaN is float
df['age'] = df['age'].astype(float) #This will work but this wont -> df['age'] = df['age'].astype(int) 
df
# Out:
#    first     last                    email   age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@gmail.com  55.0
# 2   John      Doe        JaneDoe@gmail.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@gmail.com   NaN
# 6    NaN      NaN                      NaN   NaN

# %%
type(np.NaN)  #float btw
a  = np.nan
type(a) #float btw
# Out:
# float

# %%
df.dtypes #There we go age changed t flat an NOW we can take the mean
# Out:
# first     object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# 46.75

# %%
df.astype #Random stff dunnoo what this is.
# Out:
# <bound method NDFrame.astype of    first     last                    email   age
# 0   Alex  Schafer  CoreyMSchafer@gmail.com  33.0
# 1   Jane      Doe        JaneDoe@gmail.com  55.0
# 2   John      Doe        JaneDoe@gmail.com  63.0
# 3  Chris  Schafer                     None  36.0
# 4    NaN      NaN                      NaN   NaN
# 5   None      NaN      Anonymous@gmail.com   NaN
# 6    NaN      NaN                      NaN   NaN>

# %%
import os

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Assignment 1.ipynb',
#  'Assignment 2 - Case study 2 .ipynb',
#  'Decision Tree.ipynb',
#  'Dictionaries practice for assignment.ipynb',
#  'Edureka 2 - Practice file.ipynb',
#  'Edureka Assignments.ipynb',
#  'Edureka.ipynb',
#  'k-mean cluster.ipynb',
#  'Logistic Regression .ipynb',
#  'ML - Linear Regression .ipynb',
#  'ML - Linear Regression 2.ipynb',
#  'ML.ipynb',
#  'Movie Reccomendation.ipynb',
#  'Naive Bayes Classifier + Content based filtering.ipynb',
#  'numpy.ipynb',
#  'OOPS.ipynb',
#  'Operators.ipynb',
#  'Pandas March 7th .ipynb',
#  'Pandas Practice 2 - Handling missing values.ipynb',
#  'Pandas practice.ipynb',
#  'VERY IMPORTANT BREAKDOWN OF CLASS and functions within it!.ipynb']

# %%
pwd
# Out:
# 'C:\\Users\\ABC\\6. Datasets'

# %%
import os
os.chdir('C:\\Users\\ABC\\6. Datasets')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1937_certification_project_- problem statement_v1_2kw_qmbbhat.pdf',
#  '42E17330',
#  '8qxce0lddu.xlsx',
#  'Adventure Works - Tableau Module 8 copy.csv',
#  'archive (1).zip',
#  'archive.zip',
#  'ARM - Bakery Data',
#  'ARM - Bakery Data.zip',
#  'ARM - Bakery.csv',
#  'Aug 2023 - Nov 6th 2023.xls',
#  'bank-full.csv',
#  'bank_cleaned (2).csv',
#  'bank_cleaned (3).csv',
#  'bank_cleaned.csv',
#  'BigMartSalesData.csv',
#  'BostonHousing.csv',
#  'BostonHousing2.csv',
#  'breast cancer - LogReg.csv',
#  'BX-Book-Ratings.csv',
#  'BX-Books.csv',
#  'BX-Users.csv',
#  'CalCoFi',
#  'CarPrice_Assignment.csv',
#  'Cars2015.csv',
#  'cereal.csv',
#  'CityTemps.csv',
#  "code - Nikita mam's code.ipynb",
#  'Code module 8.ipynb',
#  'CoffeeChart2.xlsx',
#  'Concrete_Data_Yeh.csv',
#  'Concrete_Data_Yeh2 - To test.csv',
#  'Credit Card Customer Data.csv',
#  'Crime_Data_from_2020_to_Present.csv',
#  'Data Dictionary - carprices.xlsx',
#  'diabetes.csv',
# ...

# %%
na_vals = ['NA', 'Missing', 'MISSING', '']
dff = pd.read_csv('survey_results_public_2020.csv',index_col = 'Respondent',  na_values = na_vals)
schema = pd.read_csv( 'survey_results_schema_2020.csv', index_col = 'Column')

# %%
schema.columns
# Out:
# Index(['QuestionText'], dtype='object')

# %%
#Average numbers of coding in no. of years among all of them 
#Good thing to knwo to compare mine against the average

# %%
dff.columns
# Out:
# Index(['MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq', 'CompTotal',
#        'ConvertedComp', 'Country', 'CurrencyDesc', 'CurrencySymbol',
#        'DatabaseDesireNextYear', 'DatabaseWorkedWith', 'DevType', 'EdLevel',
#        'Employment', 'Ethnicity', 'Gender', 'JobFactors', 'JobSat', 'JobSeek',
#        'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
dff['YearsCode'].size
# Out:
# 64461

# %%
dff['YearsCode'].unique()
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
dff['YearsCode'].replace('Less than 1 year', 0, inplace = True)
dff['YearsCode'].replace('More than 50 years', 51, inplace = True)
dff['YearsCode'].replace('nan', 0,  inplace = True)

# %%
dff['YearsCode'].unique() #BUT STILL an object so not reading it as a float
# Out:
# array([36,  7,  4, 15,  6, 17,  8, 10, 35,  5, 37, 19,  9, 22, 30, 23, 20,
#         2,  0,  3, 13, 25, 16, 43, 11, 38, 33, 24, 21, 12, 40, 27, 50, 46,
#        14, 18, 28, 32, 44, 26, 42, 31, 34, 29,  1, 39, 41, 45, 51, 47, 49,
#        48])

# %%
#df.dropna(axis = 'columns', how = 'all')

dff['YearsCode']
# Out:
# Respondent
# 1         36
# 2          7
# 3          4
# 4          7
# 5         15
#         ...
# 64858     10
# 64867    NaN
# 64898    NaN
# 64925    NaN
# 65112    NaN
# Name: YearsCode, Length: 64461, dtype: object

# %%
dff['YearsCode'] = dff['YearsCode'].astype(float)

# %%
dff['YearsCode'].dtypes
# Out:
# dtype('float64')

# %%
dff['YearsCode'].mode()
dff['YearsCode'].replace(np.nan,10 , inplace = True)

# %%
dff['YearsCode'] = dff['YearsCode'].astype(int)
dff['YearsCode']
# Out:
# 52

# %%
dff['YearsCode'].median()
# Out:
# 10.0

# %%
dff['YearsCode'].var()
# Out:
# 94.4269547811751

# %%
dff['YearsCode'].std()
# Out:
# 9.717353280661102

# %%
import sklearn as skl

# %%
getsource(skl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9428\4286200752.py in <module>
# ----> 1 getsource(skl)
#
# NameError: name 'getsource' is not defined

# %%
help(sklearn)
# Out:
# Help on package sklearn:
#
# NAME
#     sklearn
#
# DESCRIPTION
#     Machine learning module for Python
# ...
#
#     sklearn is a Python module integrating classical machine
#     learning algorithms in the tightly-knit world of scientific Python
#     packages (numpy, scipy, matplotlib).
#
#     It aims to provide simple and efficient solutions to learning problems
#     that are accessible to everybody and reusable in various contexts:
#     machine-learning as a versatile tool for science and engineering.
#
#     See http://scikit-learn.org for complete documentation.
#
# PACKAGE CONTENTS
#     __check_build (package)
#     _build_utils (package)
#     _config
#     _distributor_init
#     _isotonic
#     _loss (package)
#     _min_dependencies
#     base
#     calibration
#     cluster (package)
#     compose (package)
#     conftest
#     covariance (package)
#     cross_decomposition (package)
#     datasets (package)
#     decomposition (package)
#     discriminant_analysis
# ...

# %%
from sklearn import linear_model as lmm
from sklearn import experimental as ex
from sklearn import covariance as cov
from sklearn import datasets as dt
from sklearn import feature_selection as fs
from sklearn import naive_bayes as nb
from sklearn import preprocessing as pp
from sklearn import tree as tr
from sklearn import neural_network as nn
from sklearn import random_projection as rp
from sklearn import model_selection as ms

# %%
lm = lmm.LinearRegression()

# %%
ms.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9428\2470180237.py in <module>
# ----> 1 lm.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'

# %%
lmm.__all__
# Out:
# ['ARDRegression',
#  'BayesianRidge',
#  'ElasticNet',
#  'ElasticNetCV',
#  'Hinge',
#  'Huber',
#  'HuberRegressor',
#  'Lars',
#  'LarsCV',
#  'Lasso',
#  'LassoCV',
#  'LassoLars',
#  'LassoLarsCV',
#  'LassoLarsIC',
#  'LinearRegression',
#  'Log',
#  'LogisticRegression',
#  'LogisticRegressionCV',
#  'ModifiedHuber',
#  'MultiTaskElasticNet',
#  'MultiTaskElasticNetCV',
#  'MultiTaskLasso',
#  'MultiTaskLassoCV',
#  'OrthogonalMatchingPursuit',
#  'OrthogonalMatchingPursuitCV',
#  'PassiveAggressiveClassifier',
#  'PassiveAggressiveRegressor',
#  'Perceptron',
#  'QuantileRegressor',
#  'Ridge',
#  'RidgeCV',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SGDRegressor',
#  'SGDOneClassSVM',
#  'SquaredLoss',
#  'TheilSenRegressor',
#  'enet_path',
#  'lars_path',
#  'lars_path_gram',
#  'lasso_path',
#  'orthogonal_mp',
#  'orthogonal_mp_gram',
#  'ridge_regression',
#  'RANSACRegressor',
#  'PoissonRegressor',
#  'GammaRegressor',
# ...

# %%
sklearn.__all__
# Out:
# ['calibration',
#  'cluster',
#  'covariance',
#  'cross_decomposition',
#  'datasets',
#  'decomposition',
#  'dummy',
#  'ensemble',
#  'exceptions',
#  'experimental',
#  'externals',
#  'feature_extraction',
#  'feature_selection',
#  'gaussian_process',
#  'inspection',
#  'isotonic',
#  'kernel_approximation',
#  'kernel_ridge',
#  'linear_model',
#  'manifold',
#  'metrics',
#  'mixture',
#  'model_selection',
#  'multiclass',
#  'multioutput',
#  'naive_bayes',
#  'neighbors',
#  'neural_network',
#  'pipeline',
#  'preprocessing',
#  'random_projection',
#  'semi_supervised',
#  'svm',
#  'tree',
#  'discriminant_analysis',
#  'impute',
#  'compose',
#  'clone',
#  'get_config',
#  'set_config',
#  'config_context',
#  'show_versions']

# %%
sklearn.linear_model.__all__
# Out:
# ['ARDRegression',
#  'BayesianRidge',
#  'ElasticNet',
#  'ElasticNetCV',
#  'Hinge',
#  'Huber',
#  'HuberRegressor',
#  'Lars',
#  'LarsCV',
#  'Lasso',
#  'LassoCV',
#  'LassoLars',
#  'LassoLarsCV',
#  'LassoLarsIC',
#  'LinearRegression',
#  'Log',
#  'LogisticRegression',
#  'LogisticRegressionCV',
#  'ModifiedHuber',
#  'MultiTaskElasticNet',
#  'MultiTaskElasticNetCV',
#  'MultiTaskLasso',
#  'MultiTaskLassoCV',
#  'OrthogonalMatchingPursuit',
#  'OrthogonalMatchingPursuitCV',
#  'PassiveAggressiveClassifier',
#  'PassiveAggressiveRegressor',
#  'Perceptron',
#  'QuantileRegressor',
#  'Ridge',
#  'RidgeCV',
#  'RidgeClassifier',
#  'RidgeClassifierCV',
#  'SGDClassifier',
#  'SGDRegressor',
#  'SGDOneClassSVM',
#  'SquaredLoss',
#  'TheilSenRegressor',
#  'enet_path',
#  'lars_path',
#  'lars_path_gram',
#  'lasso_path',
#  'orthogonal_mp',
#  'orthogonal_mp_gram',
#  'ridge_regression',
#  'RANSACRegressor',
#  'PoissonRegressor',
#  'GammaRegressor',
# ...

# %%
sklearn.__all__
# Out:
# ['calibration',
#  'cluster',
#  'covariance',
#  'cross_decomposition',
#  'datasets',
#  'decomposition',
#  'dummy',
#  'ensemble',
#  'exceptions',
#  'experimental',
#  'externals',
#  'feature_extraction',
#  'feature_selection',
#  'gaussian_process',
#  'inspection',
#  'isotonic',
#  'kernel_approximation',
#  'kernel_ridge',
#  'linear_model',
#  'manifold',
#  'metrics',
#  'mixture',
#  'model_selection',
#  'multiclass',
#  'multioutput',
#  'naive_bayes',
#  'neighbors',
#  'neural_network',
#  'pipeline',
#  'preprocessing',
#  'random_projection',
#  'semi_supervised',
#  'svm',
#  'tree',
#  'discriminant_analysis',
#  'impute',
#  'compose',
#  'clone',
#  'get_config',
#  'set_config',
#  'config_context',
#  'show_versions']

# %%
sklearn.model_selection.__all__
# Out:
# ['BaseCrossValidator',
#  'BaseShuffleSplit',
#  'GridSearchCV',
#  'TimeSeriesSplit',
#  'KFold',
#  'GroupKFold',
#  'GroupShuffleSplit',
#  'LeaveOneGroupOut',
#  'LeaveOneOut',
#  'LeavePGroupsOut',
#  'LeavePOut',
#  'RepeatedKFold',
#  'RepeatedStratifiedKFold',
#  'ParameterGrid',
#  'ParameterSampler',
#  'PredefinedSplit',
#  'RandomizedSearchCV',
#  'ShuffleSplit',
#  'StratifiedKFold',
#  'StratifiedGroupKFold',
#  'StratifiedShuffleSplit',
#  'check_cv',
#  'cross_val_predict',
#  'cross_val_score',
#  'cross_validate',
#  'learning_curve',
#  'permutation_test_score',
#  'train_test_split',
#  'validation_curve']

# %%
help(sklearn)
# Out:
# Help on package sklearn:
#
# NAME
#     sklearn
#
# DESCRIPTION
#     Machine learning module for Python
# ...
#
#     sklearn is a Python module integrating classical machine
#     learning algorithms in the tightly-knit world of scientific Python
#     packages (numpy, scipy, matplotlib).
#
#     It aims to provide simple and efficient solutions to learning problems
#     that are accessible to everybody and reusable in various contexts:
#     machine-learning as a versatile tool for science and engineering.
#
#     See http://scikit-learn.org for complete documentation.
#
# PACKAGE CONTENTS
#     __check_build (package)
#     _build_utils (package)
#     _config
#     _distributor_init
#     _isotonic
#     _loss (package)
#     _min_dependencies
#     base
#     calibration
#     cluster (package)
#     compose (package)
#     conftest
#     covariance (package)
#     cross_decomposition (package)
#     datasets (package)
#     decomposition (package)
#     discriminant_analysis
# ...

# %%
import sklearn as skl

# %%
from sklearn import cluster

# %%
table = {
    
    'Age': [45,56,47,54,35,51, 34, 58, 34, 37, 31, 52, 55],
    'weight': [520,530,535,550,570,560, 756, 528, 521, 587, 543, 528, 676],
    'height' : [6,5,4.5,5.5,6,5.8, 4.7, 5.5, 6.4,6.7, 4.2, 5.3, 5.5]
    
}

# %%
df = pd.DataFrame(table)

# %%
df
# Out:
#     Age  weight  height
# 0    45     520     6.0
# 1    56     530     5.0
# 2    47     535     4.5
# 3    54     550     5.5
# 4    35     570     6.0
# 5    51     560     5.8
# 6    34     756     4.7
# 7    58     528     5.5
# 8    34     521     6.4
# 9    37     587     6.7
# 10   31     543     4.2
# 11   52     528     5.3
# 12   55     676     5.5

# %%
df[['Age', 'weight', 'height']]
# Out:
#     Age  weight  height
# 0    45     520     6.0
# 1    56     530     5.0
# 2    47     535     4.5
# 3    54     550     5.5
# 4    35     570     6.0
# 5    51     560     5.8
# 6    34     756     4.7
# 7    58     528     5.5
# 8    34     521     6.4
# 9    37     587     6.7
# 10   31     543     4.2
# 11   52     528     5.3
# 12   55     676     5.5

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(df['Age'], df['weight'], df['height'])
#??? hw 3 dimensions?

# %%
from sklearn import cluster as cl

# %%
km = cl.KMeans(n_clusters=3)

# %%
y_predicted = km.fit_predict(df)

# %%
df['cluster'] = y_predicted

# %%
df
# Out:
#     Age  weight  height  cluster
# 0    45     520     6.0        0
# 1    56     530     5.0        0
# 2    47     535     4.5        0
# 3    54     550     5.5        0
# 4    35     570     6.0        2
# 5    51     560     5.8        2
# 6    34     756     4.7        1
# 7    58     528     5.5        0
# 8    34     521     6.4        0
# 9    37     587     6.7        2
# 10   31     543     4.2        0
# 11   52     528     5.3        0
# 12   55     676     5.5        1
