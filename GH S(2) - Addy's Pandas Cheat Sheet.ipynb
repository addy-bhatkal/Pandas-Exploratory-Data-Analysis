# %%
#A Pandas CheatSheet

# %%
"S(2) - EDA + Pandas Practice" 

pd.Series(data, dtype, index, name) #format A list a numpy array and a ditionary can be converted into a series
pd.DataFrame(data, dtype, index, columns) #another argument, but DF is 2 dimensional so thus columsn also
schema = pd.read_csv('ccc.csv', index_col = 'Column') 'COlumn' is an existind name of the column in the csv
schema = pd.read_csv('ccc.csv', names/columns = [add, a, list]) 
schema = pd.read_csv('C:\\Users\\ABC\\6. Datasets\\Recommend1.csv', names/columns = ('first','second','third','fourth')) #Or add a tuple

df['Tip'].describe()
df.columns.unique()
unique_values_count = df.nunique()
df.value_counts
df.values - #df.values() is trying to call a method named values, which doesn't exist in this context. Thus, you use df.values to get an array of the DataFrame.
a = df.describe(include='all').loc['unique'] #im sure unique is the value of a column, and loc means str value 
unique_values = df.apply(lambda col: col.unique())

aa = df.apply(lambda col: col.unique())
results3 = df.groupby(['Day', 'Size']).size().unstack(fill_value = 0)

"Pandas practice"
type(s)
pd.Series(data, index, dtype, name) #format A list a numpy array and a ditionary can be converted into a series
#format A list a numpy array and a ditionary can be converted into a series
s = pd.Series(data, dtype = 'float', name = 'series 1') #Series is case sensitive
df = pd.DataFrame(data = , index=, columns =,  dtype)
df = pd.DataFrame(data = [[1,2,3], [4,5,6]], index=range(0,2), columns = ['A', 'B', 'C'], dtype = float) #columns come in sq brackets


d2 = np.random.randn(5) - output is an array - as is the case in all of np? 

csv cant have sheets, only excels files can! So, see that code says pd.csv_excel(..)
path name extension is xlsx not xslx! 
dir(pd)
dir(math)
df.columns, df.size, df.shape
df[['Absences', 'EngagementSurvey', 'EmpSatisfaction','SpecialProjectsCount']] - df from a df
df.info()
df.isnull()
df.isnull().sum()
df.isnull().sum().sum()
df[['Absences', 'Employee_Name'] [0:3]] #columns slicing inside the square brackets
v/s
df[['Absences', 'Employee_Name']][0:3]
Magic of double [[]]
df[(df['MarriedID'] == 1) & (df['GenderID'] == 1)] #Use the '&' for multiple filters
a = df['MarriedID'] != 1
a.count()
pd.read_excel('practice1.xlsx', sheet_name = [2]) #relative path
df.sort_values('PositionID')
df.sort_values('Salary', ascending = False)
df.rename(columns={'Salary':'Pay'}) #NOTICE the dictionary in rename!!!!!
df['new'] = df['Salary'] * df['DeptID']
df['new'] = df['EngagementSurvey'] * df['EmpSatisfaction']
df.pivot_table(index=['Salary'], columns =['GenderID'], values = 'RecruitmentSource')
df.plot('EngagementSurvey')
pd.set_option('display.max_rows', None)
df.iloc[0:10, 0:12].sort_values(['PerfScoreID', 'GenderID'])

arr = np.random.randn(4, 5)
pd.DataFrame(data = arr, columns = [5,4,3,2,1])
pd.DataFrame(a, columns = ['a', 'b', 'c', 'd', 'e'])

df.set_index('First Name', inplace = True) #settting a new index
df.loc['Fred'] # Respective data on Fred #VERY COOL!
ddf.sort_index().head() #OR ddf.sort_index(ascending = False)
schema = pd.read_csv('ccc.csv', index_col = 'Column')
schema.loc['ProgramHobby', 'Question'] - index value + column2 header - for specific information 
schema['Question'] !=  "When on"
filt = (dff['ProgramHobby'] == 'Yes, both')
dff.loc[filt, ['Professional', 'Respondent']] #they both are column headers

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('C:\\Users\\ABC\\5. Pandas practice\\HRDataset_v14.xlsx', names = ['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
       'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
       'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
       'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
       'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
       'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
       'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
       'Absences'])
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
df
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
b = df[['ManagerName', 'ManagerID', 'RecruitmentSource',
       'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount']][0:4]
b
# Out:
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount
# 0              4.60                5                     0
# 1              4.96                3                     6
# 2              3.02                3                     0
# 3              4.84                5                     0

# %%
df.sort_values('ManagerID')
# Out:
#             Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 132       Howard, Estelle  10182          1                1         0
# 160  LaRotonda, William    10038          0                2         1
# 268      Steans, Tyrone    10147          0                0         1
# 255           Singh, Nan   10039          0                0         0
# 29             Brown, Mia  10238          1                1         0
# ..                    ...    ...        ...              ...       ...
# 88        Fancett, Nicole  10136          0                0         0
# 135       Hutter, Rosalie  10214          0                3         0
# 177     Manchester, Robyn  10077          1                1         0
# 232       Rivera, Haley    10011          1                1         0
# 251        Sewkumar, Nori  10071          0                0         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# ...

# %%
b = df[['ManagerName', 'ManagerID', 'RecruitmentSource',
       'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
       'SpecialProjectsCount']][0:4]
b
# Out:
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# 0  Michael Albert       22.0          LinkedIn          Exceeds
# 1      Simon Roup        4.0            Indeed      Fully Meets
# 2  Kissy Sullivan       20.0          LinkedIn      Fully Meets
# 3    Elijiah Gray       16.0            Indeed      Fully Meets
#
#    EngagementSurvey  EmpSatisfaction  SpecialProjectsCount
# 0              4.60                5                     0
# 1              4.96                3                     6
# 2              3.02                3                     0
# 3              4.84                5                     0

# %%
df.iloc[0:10, 0:12].sort_values(['PerfScoreID', 'GenderID'])
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
# 6           Andreola, Colby  10194          0                0         0
# 8          Bachiochi, Linda  10114          0                0         0
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 7               Athwal, Sam  10062          0                4         1
# 9        Bacong, Alejandro   10250          0                2         1
# 5         Anderson, Linda    10002          0                0         0
# 0       Adinolfi, Wilson  K  10026          0                0         1
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  Termd  \
# 2            5       5            3                       0   64955      1
# ...

# %%
df.set_index('Employee_Name', inplace = True)
df
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
# ...                         ...        ...              ...       ...
# Woodson, Jason            10135          0                0         1
# Ybarra, Catherine         10301          0                0         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
df.loc['Akinkuolie, Sarah']
# Out:
# EmpID                                            10196
# MarriedID                                            1
# MaritalStatusID                                      1
# GenderID                                             0
# EmpStatusID                                          5
# DeptID                                               5
# PerfScoreID                                          3
# FromDiversityJobFairID                               0
# Salary                                           64955
# Termd                                                1
# PositionID                                          20
# Position                      Production Technician II
# State                                               MA
# Zip                                               1810
# DOB                                1988-09-19 00:00:00
# Sex                                                  F
# MaritalDesc                                    Married
# ...

# %%
df
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
# ...                         ...        ...              ...       ...
# Woodson, Jason            10135          0                0         1
# Ybarra, Catherine         10301          0                0         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...

# %%
x = np.ones((311))
pd.DataFrame(x, index = df.index, columns=['value'], dtype = object) #Cnverted an array to a df and even a series
pd.Series(x, index = df.index)
# Out:
# Employee_Name
# Adinolfi, Wilson  K         1.0
# Ait Sidi, Karthikeyan       1.0
# Akinkuolie, Sarah           1.0
# Alagbe,Trina                1.0
# Anderson, Carol             1.0
#                            ...
# Woodson, Jason              1.0
# Ybarra, Catherine           1.0
# Zamora, Jennifer            1.0
# Zhou, Julia                 1.0
# Zima, Colleen               1.0
# Length: 311, dtype: float64

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Carol           10069          0                2         0
# ...                         ...        ...              ...       ...
# Woodson, Jason            10135          0                0         1
# Ybarra, Catherine         10301          0                0         0
# Zamora, Jennifer          10010          0                0         0
# Zhou, Julia               10043          0                0         0
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# ...

# %%
filterr = df['MaritalStatusID']==1

# %%
df.loc[filterr, ['EmpID', 'EmpStatusID']]
# Out:
#                           EmpID  EmpStatusID
# Employee_Name
# Ait Sidi, Karthikeyan     10084            5
# Akinkuolie, Sarah         10196            5
# Alagbe,Trina              10088            1
# Baczenski, Rachael        10252            5
# Barbara, Thomas           10242            5
# ...                         ...          ...
# Valentin,Jackie           10205            1
# Voldemort, Lord           10118            4
# Volk, Colleen             10022            4
# Wallace, Courtney  E      10274            5
# Wilber, Barry             10048            5
#
# [124 rows x 2 columns]

# %%
Recruitment_Source = ['LinkedIn', 'Indeed']
date = df['RecruitmentSource'].isin(Recruitment_Source)

# %%
df[date]
# Out:
#                           EmpID  MarriedID  MaritalStatusID  GenderID  \
# Employee_Name
# Adinolfi, Wilson  K       10026          0                0         1
# Ait Sidi, Karthikeyan     10084          1                1         1
# Akinkuolie, Sarah         10196          1                1         0
# Alagbe,Trina              10088          1                1         0
# Anderson, Linda           10002          0                0         0
# ...                         ...        ...              ...       ...
# Whittier, Scott           10072          0                0         1
# Winthrop, Jordan          10033          0                0         1
# Wolk, Hang  T             10174          0                0         0
# Woodson, Jason            10135          0                0         1
# Zima, Colleen             10271          0                4         0
#
#                           EmpStatusID  DeptID  PerfScoreID  \
# Employee_Name
# ...
