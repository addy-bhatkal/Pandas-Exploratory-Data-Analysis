# %%
import os
import pandas as pd
import numpy as np

# %%
os.chdir('C:\\Users\\ABC\\6. Datasets')
df = pd.read_csv('tips.csv')
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.apply(lambda col: col.unique())
# Out:
# Total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                              [Female, Male]
# Smoker                                                [No, Yes]
# Day                                       [Sun, Sat, Thur, Fri]
# Time                                            [Dinner, Lunch]
# Size                                         [2, 3, 4, 1, 6, 5]
# dtype: object

# %%
df = df.reset_index()
df
# Out:
#      index  Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0        0       16.99  1.01  Female     No   Sun  Dinner     2
# 1        1       10.34  1.66    Male     No   Sun  Dinner     3
# 2        2       21.01  3.50    Male     No   Sun  Dinner     3
# 3        3       23.68  3.31    Male     No   Sun  Dinner     2
# 4        4       24.59  3.61  Female     No   Sun  Dinner     4
# ..     ...         ...   ...     ...    ...   ...     ...   ...
# 239    239       29.03  5.92    Male     No   Sat  Dinner     3
# 240    240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242    242       17.82  1.75    Male     No   Sat  Dinner     2
# 243    243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df = df.set_index('Sex')
df
# Out:
#         index  Total_bill   Tip Smoker   Day    Time  Size
# Sex
# Female      0       16.99  1.01     No   Sun  Dinner     2
# Male        1       10.34  1.66     No   Sun  Dinner     3
# Male        2       21.01  3.50     No   Sun  Dinner     3
# Male        3       23.68  3.31     No   Sun  Dinner     2
# Female      4       24.59  3.61     No   Sun  Dinner     4
# ...       ...         ...   ...    ...   ...     ...   ...
# Male      239       29.03  5.92     No   Sat  Dinner     3
# Female    240       27.18  2.00    Yes   Sat  Dinner     2
# Male      241       22.67  2.00    Yes   Sat  Dinner     2
# Male      242       17.82  1.75     No   Sat  Dinner     2
# Female    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = df.reset_index()
df
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 1      Male      1       10.34  1.66     No   Sun  Dinner     3
# 2      Male      2       21.01  3.50     No   Sun  Dinner     3
# 3      Male      3       23.68  3.31     No   Sun  Dinner     2
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# ..      ...    ...         ...   ...    ...   ...     ...   ...
# 239    Male    239       29.03  5.92     No   Sat  Dinner     3
# 240  Female    240       27.18  2.00    Yes   Sat  Dinner     2
# 241    Male    241       22.67  2.00    Yes   Sat  Dinner     2
# 242    Male    242       17.82  1.75     No   Sat  Dinner     2
# 243  Female    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
filt = df[(df['Sex']=='Male') & (df['Smoker']=='No')]
Day = ['Sat', 'Sun']
filt3 = df['Day'].isin(['Sat', 'Sun']) #or just put Day here which is alerady an object
df[filt3]
# Out:
#         Sex  index  Total_bill   Tip Smoker  Day    Time  Size
# 0    Female      0       16.99  1.01     No  Sun  Dinner     2
# 1      Male      1       10.34  1.66     No  Sun  Dinner     3
# 2      Male      2       21.01  3.50     No  Sun  Dinner     3
# 3      Male      3       23.68  3.31     No  Sun  Dinner     2
# 4    Female      4       24.59  3.61     No  Sun  Dinner     4
# ..      ...    ...         ...   ...    ...  ...     ...   ...
# 238  Female    238       35.83  4.67     No  Sat  Dinner     3
# 239    Male    239       29.03  5.92     No  Sat  Dinner     3
# 240  Female    240       27.18  2.00    Yes  Sat  Dinner     2
# 241    Male    241       22.67  2.00    Yes  Sat  Dinner     2
# 242    Male    242       17.82  1.75     No  Sat  Dinner     2
#
# [163 rows x 8 columns]

# %%
size = [2,3,4,5]
df[df['Size'].isin(size)]
d = df[df['Size']==4]
listy = list(d['index'])
e = df[df['Smoker']=='No']
e_filtered = e[e['index'].isin(listy)]
e_filtered
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# 5      Male      5       25.29  4.71     No   Sun  Dinner     4
# 7      Male      7       26.88  3.12     No   Sun  Dinner     4
# 11   Female     11       35.26  5.00     No   Sun  Dinner     4
# 13     Male     13       18.43  3.00     No   Sun  Dinner     4
# 23     Male     23       39.42  7.58     No   Sat  Dinner     4
# 25     Male     25       17.81  2.34     No   Sat  Dinner     4
# 31     Male     31       18.35  2.50     No   Sat  Dinner     4
# 33   Female     33       20.69  2.45     No   Sat  Dinner     4
# 44     Male     44       30.40  5.60     No   Sun  Dinner     4
# 47     Male     47       32.40  6.00     No   Sun  Dinner     4
# 52   Female     52       34.81  5.20     No   Sun  Dinner     4
# 54     Male     54       25.56  4.34     No   Sun  Dinner     4
# 59     Male     59       48.27  6.73     No   Sat  Dinner     4
# ...

# %%
df
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 1      Male      1       10.34  1.66     No   Sun  Dinner     3
# 2      Male      2       21.01  3.50     No   Sun  Dinner     3
# 3      Male      3       23.68  3.31     No   Sun  Dinner     2
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# ..      ...    ...         ...   ...    ...   ...     ...   ...
# 239    Male    239       29.03  5.92     No   Sat  Dinner     3
# 240  Female    240       27.18  2.00    Yes   Sat  Dinner     2
# 241    Male    241       22.67  2.00    Yes   Sat  Dinner     2
# 242    Male    242       17.82  1.75     No   Sat  Dinner     2
# 243  Female    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
#Females with size 2 - used a listy index approach. 

g = df.groupby(['Sex', 'Size'])
g.get_group(('Female', 2))
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 14   Female     14       14.83  3.02     No   Sun  Dinner     2
# 21   Female     21       20.29  2.75     No   Sat  Dinner     2
# 22   Female     22       15.77  2.23     No   Sat  Dinner     2
# 29   Female     29       19.65  3.00     No   Sat  Dinner     2
# 32   Female     32       15.06  3.00     No   Sat  Dinner     2
# 51   Female     51       10.29  2.60     No   Sun  Dinner     2
# 57   Female     57       26.41  1.50     No   Sat  Dinner     2
# 66   Female     66       16.45  2.47     No   Sat  Dinner     2
# 72   Female     72       26.86  3.14    Yes   Sat  Dinner     2
# 73   Female     73       25.28  5.00    Yes   Sat  Dinner     2
# 74   Female     74       14.73  2.20     No   Sat  Dinner     2
# 92   Female     92        5.75  1.00    Yes   Fri  Dinner     2
# 93   Female     93       16.32  4.30    Yes   Fri  Dinner     2
# ...

# %%
c = list(df['Tip'] )

# %%
a = df.groupby(['Sex', 'Smoker'])
a.get_group(('Female', 'No'))
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# 11   Female     11       35.26  5.00     No   Sun  Dinner     4
# 14   Female     14       14.83  3.02     No   Sun  Dinner     2
# 16   Female     16       10.33  1.67     No   Sun  Dinner     3
# 18   Female     18       16.97  3.50     No   Sun  Dinner     3
# 21   Female     21       20.29  2.75     No   Sat  Dinner     2
# 22   Female     22       15.77  2.23     No   Sat  Dinner     2
# 29   Female     29       19.65  3.00     No   Sat  Dinner     2
# 32   Female     32       15.06  3.00     No   Sat  Dinner     2
# 33   Female     33       20.69  2.45     No   Sat  Dinner     4
# 37   Female     37       16.93  3.07     No   Sat  Dinner     3
# 51   Female     51       10.29  2.60     No   Sun  Dinner     2
# 52   Female     52       34.81  5.20     No   Sun  Dinner     4
# ...

# %%
"""i = pd.DataFrame(df[['Time', 'Sex', 'Size']], dtype= str, index = df.index, columns = {1: 'Time', 2: 'Sex', 3: 'Size'})"""
# Out:
# "i = pd.DataFrame(df[['Time', 'Sex', 'Size']], dtype= str, index = df.index, columns = {1: 'Time', 2: 'Sex', 3: 'Size'})"

# %%
df
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 1      Male      1       10.34  1.66     No   Sun  Dinner     3
# 2      Male      2       21.01  3.50     No   Sun  Dinner     3
# 3      Male      3       23.68  3.31     No   Sun  Dinner     2
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# ..      ...    ...         ...   ...    ...   ...     ...   ...
# 239    Male    239       29.03  5.92     No   Sat  Dinner     3
# 240  Female    240       27.18  2.00    Yes   Sat  Dinner     2
# 241    Male    241       22.67  2.00    Yes   Sat  Dinner     2
# 242    Male    242       17.82  1.75     No   Sat  Dinner     2
# 243  Female    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df[['Sex','index','Day'][0:3]]
# Out:
#         Sex  index   Day
# 0    Female      0   Sun
# 1      Male      1   Sun
# 2      Male      2   Sun
# 3      Male      3   Sun
# 4    Female      4   Sun
# ..      ...    ...   ...
# 239    Male    239   Sat
# 240  Female    240   Sat
# 241    Male    241   Sat
# 242    Male    242   Sat
# 243  Female    243  Thur
#
# [244 rows x 3 columns]

# %%
df
# Out:
#         Sex  index  Total_bill   Tip Smoker   Day    Time  Size
# 0    Female      0       16.99  1.01     No   Sun  Dinner     2
# 1      Male      1       10.34  1.66     No   Sun  Dinner     3
# 2      Male      2       21.01  3.50     No   Sun  Dinner     3
# 3      Male      3       23.68  3.31     No   Sun  Dinner     2
# 4    Female      4       24.59  3.61     No   Sun  Dinner     4
# ..      ...    ...         ...   ...    ...   ...     ...   ...
# 239    Male    239       29.03  5.92     No   Sat  Dinner     3
# 240  Female    240       27.18  2.00    Yes   Sat  Dinner     2
# 241    Male    241       22.67  2.00    Yes   Sat  Dinner     2
# 242    Male    242       17.82  1.75     No   Sat  Dinner     2
# 243  Female    243       18.78  3.00     No  Thur  Dinner     2
#
# [244 rows x 8 columns]

# %%
df.pivot_table(index = 'Sex', columns = ['Day'], values = 'Tip')
# Out:
# Day          Fri       Sat       Sun      Thur
# Sex
# Female  2.781111  2.801786  3.367222  2.575625
# Male    2.693000  3.083898  3.220345  2.980333

# %%
dff = pd.read_csv('C:\\Users\\ABC\\6. Datasets\\Pandas practice Corey Schafer\\survey_results_public.csv')
dff.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
dff.pivot_table(index = 'Country', columns = 'ProgramHobby', values = 'ExpectedSalary')
# Out:
# ProgramHobby     No  Yes, I contribute to open source projects  \
# Country
# Afghanistan     NaN                                        NaN
# Albania         NaN                                  645.16129
# Algeria         NaN                                 6000.00000
# Andorra         NaN                                        NaN
# Antarctica      NaN                                        NaN
# ...             ...                                        ...
# Uruguay         NaN                                        NaN
# Uzbekistan      NaN                                        NaN
# Venezuela       NaN                                31000.00000
# Vietnam         NaN                                        NaN
# Zimbabwe      800.0                                        NaN
#
# ProgramHobby  Yes, I program as a hobby     Yes, both
# Country
# Afghanistan                  757.575758           NaN
# Albania                     1290.322581   1075.268817
# ...

# %%
ddf = pd.read_csv('C:\\Users\\ABC\\6. Datasets\\prisoners.csv') # TO set index from the start

ddf.set_index('STATE/UT', inplace = True)
ddf
e = pd.DataFrame(ddf.loc['Assam'])
e
ddf.loc['Haryana', 'No. of Inmates benefitted by Elementary Education']
# Out:
# 1131

# %%
ddf

"""filt = (dff['ProgramHobby'] == 'Yes, both')
dff.loc[filt, ['Professional', 'Respondent']] #they both are column headers"""
# Out:
# "filt = (dff['ProgramHobby'] == 'Yes, both')\ndff.loc[filt, ['Professional', 'Respondent']] #they both are column headers"

# %%
ddf.head(1)
# Out:
#                 YEAR  No. of Inmates benefitted by Elementary Education  \
# STATE/UT
# Andhra Pradesh  2013                                               9480
#
#                 No. of Inmates benefitted by Adult Education  \
# STATE/UT
# Andhra Pradesh                                         13758
#
#                 No. of Inmates benefitted by Higher Education  \
# STATE/UT
# Andhra Pradesh                                            672
#
#                 No. of Inmates benefitted by Computer Course
# STATE/UT
# Andhra Pradesh                                           170

# %%
ddf
filtt = (ddf['No. of Inmates benefitted by Elementary Education']>3000)
ddf.loc[filtt, ['No. of Inmates benefitted by Higher Education','No. of Inmates benefitted by Adult Education' ]]
ddf.loc[filtt]
# Out:
#                 YEAR  No. of Inmates benefitted by Elementary Education  \
# STATE/UT
# Andhra Pradesh  2013                                               9480
# Jharkhand       2013                                               3008
# Uttar Pradesh   2013                                               7876
#
#                 No. of Inmates benefitted by Adult Education  \
# STATE/UT
# Andhra Pradesh                                         13758
# Jharkhand                                               2595
# Uttar Pradesh                                           8093
#
#                 No. of Inmates benefitted by Higher Education  \
# STATE/UT
# Andhra Pradesh                                            672
# Jharkhand                                                 138
# Uttar Pradesh                                            1353
#
#                 No. of Inmates benefitted by Computer Course
# STATE/UT
# Andhra Pradesh                                           170
# ...

# %%
ddf.loc['Assam','No. of Inmates benefitted by Elementary Education']
# Out:
# 676

# %% [markdown]
# # Pandas GOI set

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.nunique()
# Out:
# Total_bill    229
# Tip           123
# Sex             2
# Smoker          2
# Day             4
# Time            2
# Size            6
# dtype: int64

# %%
unique_values = df.apply(lambda col: col.unique())
unique_values
# Out:
# Total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                              [Female, Male]
# Smoker                                                [No, Yes]
# Day                                       [Sun, Sat, Thur, Fri]
# Time                                            [Dinner, Lunch]
# Size                                         [2, 3, 4, 1, 6, 5]
# dtype: object

# %%
uv = ddf.apply(lambda col: col.unique())
uv
# Out:
# YEAR                                                                                            [2013]
# No. of Inmates benefitted by Elementary Education    [9480, 0, 676, 1693, 1664, 7, 2310, 1131, 33, ...
# No. of Inmates benefitted by Adult Education         [13758, 0, 750, 3013, 1803, 3133, 774, 80, 124...
# No. of Inmates benefitted by Higher Education        [672, 0, 14, 125, 192, 6, 875, 1112, 26, 33, 1...
# No. of Inmates benefitted by Computer Course         [170, 0, 30, 1417, 103, 88, 966, 243, 34, 574,...
# dtype: object

# %%
ddf.head(2)
# Out:
#                    YEAR  No. of Inmates benefitted by Elementary Education  \
# STATE/UT
# Andhra Pradesh     2013                                               9480
# Arunachal Pradesh  2013                                                  0
#
#                    No. of Inmates benefitted by Adult Education  \
# STATE/UT
# Andhra Pradesh                                            13758
# Arunachal Pradesh                                             0
#
#                    No. of Inmates benefitted by Higher Education  \
# STATE/UT
# Andhra Pradesh                                               672
# Arunachal Pradesh                                              0
#
#                    No. of Inmates benefitted by Computer Course
# STATE/UT
# Andhra Pradesh                                              170
# Arunachal Pradesh                                             0

# %%
dff.head(2)

# %%
for i in dff['ProgramHobby'].unique():
    print(i)

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# Total_bill [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
uv = df.apply(lambda col:col.unique())
uv
# Out:
# Total_bill    [16.99, 10.34, 21.01, 23.68, 24.59, 25.29, 8.7...
# Tip           [1.01, 1.66, 3.5, 3.31, 3.61, 4.71, 2.0, 3.12,...
# Sex                                              [Female, Male]
# Smoker                                                [No, Yes]
# Day                                       [Sun, Sat, Thur, Fri]
# Time                                            [Dinner, Lunch]
# Size                                         [2, 3, 4, 1, 6, 5]
# dtype: object

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# Total_bill [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
uv2 = ddf.apply(lambda col: col.unique())
uv2
# Out:
# YEAR                                                                                            [2013]
# No. of Inmates benefitted by Elementary Education    [9480, 0, 676, 1693, 1664, 7, 2310, 1131, 33, ...
# No. of Inmates benefitted by Adult Education         [13758, 0, 750, 3013, 1803, 3133, 774, 80, 124...
# No. of Inmates benefitted by Higher Education        [672, 0, 14, 125, 192, 6, 875, 1112, 26, 33, 1...
# No. of Inmates benefitted by Computer Course         [170, 0, 30, 1417, 103, 88, 966, 243, 34, 574,...
# dtype: object

# %%
uv3 = ddf.apply(lambda col:col.unique())
uv3
# Out:
# YEAR                                                                                            [2013]
# No. of Inmates benefitted by Elementary Education    [9480, 0, 676, 1693, 1664, 7, 2310, 1131, 33, ...
# No. of Inmates benefitted by Adult Education         [13758, 0, 750, 3013, 1803, 3133, 774, 80, 124...
# No. of Inmates benefitted by Higher Education        [672, 0, 14, 125, 192, 6, 875, 1112, 26, 33, 1...
# No. of Inmates benefitted by Computer Course         [170, 0, 30, 1417, 103, 88, 966, 243, 34, 574,...
# dtype: object

# %%
for i in uv3.index:
    print(uv3[i])
# Out:
# [2013]
# [9480    0  676 1693 1664    7 2310 1131   33  102 3008  633  156 1978
#   346    1  622  325 1050   68   15 7876  205 2023  167 1458]
# [13758     0   750  3013  1803  3133   774    80   124  2595   568    96
#   9574  2743    30    25   613   606   237  1664    13  8093    42  1889
#     45   265  1187]
# [ 672    0   14  125  192    6  875 1112   26   33  138  170   24  301
#   882   18  277  112   64  757    4 1353   29  123   11   85  908]
# [ 170    0   30 1417  103   88  966  243   34  574   12  250  151 1330
#   384  168   38  478    2  212   72  460  174]

# %%
df.groupby(['Sex','Smoker', 'Day'])['Size'].size().unstack()
# Out:
# Day            Fri  Sat  Sun  Thur
# Sex    Smoker
# Female No        2   13   14    25
#        Yes       7   15    4     7
# Male   No        2   32   43    20
#        Yes       8   27   15    10

# %%
df.groupby('Day')['Day'].count()
# Out:
# Day
# Fri     19
# Sat     87
# Sun     76
# Thur    62
# Name: Day, dtype: int64

# %%
df
# Out:
#      Total_bill   Tip     Sex Smoker   Day    Time  Size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
a = df.groupby('Size')['Total_bill'].sum()
b = pd.DataFrame(a)
b.reset_index(inplace = True)
b
d = pd.DataFrame(df.groupby('Size')['Tip'].sum())
d.reset_index(inplace=True)
d
# Out:
#    Size     Tip
# 0     1    5.75
# 1     2  402.84
# 2     3  128.94
# 3     4  153.01
# 4     5   20.14
# 5     6   20.90

# %%
b['Bill_for_Size'] = b['Total_bill']/b['Size']

# %%
e[e['Size']==2].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16836\4148513447.py in <module>
# ----> 1 e[e['Size']==2].count()
#
# NameError: name 'e' is not defined

# %%
e = pd.merge(b,d, on='Size')
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16836\1226975343.py in <module>
# ----> 1 e = pd.merge(b,d, on='Size')
#       2 e
#
# NameError: name 'b' is not defined

# %%
e['Average_Tip_per_Size'] = e['Total_bill']/e['Tip']
#e.drop('Average_Tip_per_Size', axis = 1, inplace = True)

# %%
plt.plot(e['Size'], e['Average_Tip_per_Size'],  '--')

# %%
e
# Out:
#    Size  Total_bill  Bill_for_Size     Tip  Average_Tip_per_Size
# 0     1       28.97         28.970    5.75              5.038261
# 1     2     2565.89       1282.945  402.84              6.369502
# 2     3      884.55        294.850  128.94              6.860168
# 3     4     1058.70        264.675  153.01              6.919156
# 4     5      150.34         30.068   20.14              7.464747
# 5     6      139.32         23.220   20.90              6.666029

# %%
for size in range(0, e['Size'].shape[0] +1):
    print(size, e[e['Size']==size]['Average_Tip_per_Size'].sum())
# Out:
# 0 0.0
# 1 5.038260869565217
# 2 6.369501539072584
# 3 6.86016751977664
# 4 6.919155610744396
# 5 7.464746772591857
# 6 6.666028708133972

# %%
e[e['Size']==2]['Average_Tip_per_Size']
# Out:
# 1    6.369502
# Name: Average_Tip_per_Size, dtype: float64
